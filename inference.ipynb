# %% [markdown]
# # Importing Dependencies

# %%
import numpy as np 
import pandas as pd
import matplotlib.pylab as plt
import cv2
import os
import tensorflow as tf
from glob import glob
from tqdm import tqdm
import time
import tensorflow.keras.backend as K
from functools import reduce

# %% [markdown]
# # User Directory

# %%
# set to be predicted dataset path 
data_path = "./PS3_Test/seq_4/frames/"

# %%
# set save path directory
save_path = './PS3_Test/seq_4/save'
if not os.path.exists(save_path):
    os.mkdir(save_path)
else:
    print('Folder already exists.')
# Out:
# Folder already exists.

# %%
height = 1024//4 # Set height of your frame
width = 1280//4 # Set width of input frame

classes_and_colors = np.array([[0,0,0] ,[0,0,255], [187,155,25], 
                      [0,255,125], [255,255,125], [123,15,175],
                      [12,255,141] ])

# %%
# set model path for each U-NET
model_files = ['./model/updt/unet_jacc_N1.h5',
               "./model/updt/unet_jacc_N2.h5",
               "./model/updt/unet_jacc_N3.h5",
               "./model/updt/unet_jacc_N5.h5"]

# %% [markdown]
# # U-NET Model Functions

# %%
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

# %%
def jaccard_distance(y_true, y_pred, smooth=100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.abs(y_true) + K.abs(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return (1 - jac) * smooth

# %%
def dice_loss(y_true, y_pred, smooth=1):
    intersection = K.sum(y_true * y_pred)
    sum_ = K.sum(y_true) + K.sum(y_pred)
    dice = (2. * intersection + smooth) / (sum_ + smooth)
    return 1 - dice

# %%
def load_model(model_path : str, jacc = 0):
    if jacc == 0:
        return tf.keras.models.load_model(model_path, custom_objects={'jaccard_distance': jaccard_distance})
    else:
        return tf.keras.models.load_model(model_path, custom_objects={'dice_loss': dice_loss})

# %%
def change_color_of_binary_mask(image : list, class_id : int):
    return np.array([ [ classes_and_colors[class_id] if pixel == 255 \
            else classes_and_colors[0] for pixel in row ] for row in image ])

# %%
def get_class_wise_predicted_mask ( x , class_id, jacc ) :
    name = x.split('/')[-1]
    
    x = cv2.imread ( x , cv2.IMREAD_COLOR )
    x = cv2.resize ( x , ( width , height ) )
    x = x / 255.0
    x = np.expand_dims ( x , axis = 0 )
    
    model = load_model(model_files[class_id-1],jacc)
    print(model_files[class_id-1])

    p = model.predict(x)[0]
    
    p = p > 0.5
    p = p * 255

    p = np.squeeze(p,axis=-1)

    colored_mask = change_color_of_binary_mask( p ,class_id)
    
    return colored_mask.astype(np.uint8)

# %% [markdown]
# # Prediction

# %%
def concatenate_masks( first_mask, second_mask ):
    return [[ second_mask [ row_index ][ col_index ] or pixel \
            for col_index , pixel in enumerate ( row ) ]\
            for row_index , row in enumerate ( first_mask ) ]

def concatenate_masks_rgb(first_mask, second_mask):
    return [[
        [second_mask[row_index][col_index][channel] or pixel[channel]
         for channel in range(3)]  # Iterate over RGB channels
        for col_index, pixel in enumerate(row)]
        for row_index, row in enumerate(first_mask)]

def concatenate_class_wise_masks ( image_path : str, num_of_classes = 6 ):
    jacc_class = [ '',0,1,0,1 ]
    image = cv2.imread ( image_path )
    h, w, _ = image.shape

    blank_canvas = np.zeros(( 256 , 320, 3 ))

    predicted_masks = [ get_class_wise_predicted_mask( image_path, class_id, jacc = jacc_class[class_id] ) \
                       for class_id in range ( 1 , num_of_classes + 1 )]  
    
    predicted_masks.append(blank_canvas)

    #plt.imshow(predicted_masks[0])
    #plt.imshow(predicted_masks[1])
                                
    return np.array(reduce( concatenate_masks_rgb , predicted_masks ))

# %% [markdown]
# # Driver Code

# %%
for img in os.listdir(data_path):
    img_path = os.path.join(data_path, img)
    final_img = concatenate_class_wise_masks (img_path, 4)
    plt.imsave(os.path.join(save_path, f'{img}'), final_img)

print('\nDone')
# Out:
# ./model/updt/unet_jacc_N1.h5
# 1/1 [==============================] - 10s 10s/step
# ./model/updt/unet_jacc_N2.h5
# 1/1 [==============================] - 0s 320ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 322ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 0s 303ms/step
# ./model/updt/unet_jacc_N1.h5
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001E71EA6D7E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 312ms/step
# ./model/updt/unet_jacc_N2.h5
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001E71EA6E5F0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 308ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 313ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 0s 303ms/step
# ./model/updt/unet_jacc_N1.h5
# 1/1 [==============================] - 0s 312ms/step
# ./model/updt/unet_jacc_N2.h5
# 1/1 [==============================] - 0s 323ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 304ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 0s 316ms/step
# ./model/updt/unet_jacc_N1.h5
# 1/1 [==============================] - 0s 310ms/step
# ./model/updt/unet_jacc_N2.h5
# 1/1 [==============================] - 0s 321ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 318ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 0s 306ms/step
# ./model/updt/unet_jacc_N1.h5
# 1/1 [==============================] - 0s 317ms/step
# ./model/updt/unet_jacc_N2.h5
# 1/1 [==============================] - 0s 302ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 299ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 0s 352ms/step
# ./model/updt/unet_jacc_N1.h5
# 1/1 [==============================] - 0s 309ms/step
# ./model/updt/unet_jacc_N2.h5
# 1/1 [==============================] - 0s 309ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 326ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 0s 314ms/step
# ./model/updt/unet_jacc_N1.h5
# 1/1 [==============================] - 0s 306ms/step
# ./model/updt/unet_jacc_N2.h5
# 1/1 [==============================] - 0s 303ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 347ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 0s 297ms/step
# ./model/updt/unet_jacc_N1.h5
# 1/1 [==============================] - 0s 302ms/step
# ./model/updt/unet_jacc_N2.h5
# 1/1 [==============================] - 0s 315ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 306ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 0s 334ms/step
# ./model/updt/unet_jacc_N1.h5
# 1/1 [==============================] - 0s 311ms/step
# ./model/updt/unet_jacc_N2.h5
# 1/1 [==============================] - 0s 300ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 305ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 0s 468ms/step
# ./model/updt/unet_jacc_N1.h5
# 1/1 [==============================] - 0s 303ms/step
# ./model/updt/unet_jacc_N2.h5
# 1/1 [==============================] - 0s 307ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 310ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 0s 314ms/step
# ./model/updt/unet_jacc_N1.h5
# 1/1 [==============================] - 0s 313ms/step
# ./model/updt/unet_jacc_N2.h5
# 1/1 [==============================] - 0s 296ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 306ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 0s 319ms/step
# ./model/updt/unet_jacc_N1.h5
# 1/1 [==============================] - 0s 308ms/step
# ./model/updt/unet_jacc_N2.h5
# 1/1 [==============================] - 0s 313ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 312ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 0s 307ms/step
# ./model/updt/unet_jacc_N1.h5
# 1/1 [==============================] - 0s 308ms/step
# ./model/updt/unet_jacc_N2.h5
# 1/1 [==============================] - 0s 308ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 302ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 0s 304ms/step
# ./model/updt/unet_jacc_N1.h5
# 1/1 [==============================] - 0s 365ms/step
# ./model/updt/unet_jacc_N2.h5
# 1/1 [==============================] - 0s 448ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 306ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 0s 330ms/step
# ./model/updt/unet_jacc_N1.h5
# 1/1 [==============================] - 0s 355ms/step
# ./model/updt/unet_jacc_N2.h5
# 1/1 [==============================] - 0s 366ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 405ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 0s 322ms/step
# ./model/updt/unet_jacc_N1.h5
# 1/1 [==============================] - 0s 448ms/step
# ./model/updt/unet_jacc_N2.h5
# 1/1 [==============================] - 0s 305ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 300ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 1s 534ms/step
# ./model/updt/unet_jacc_N1.h5
# 1/1 [==============================] - 0s 312ms/step
# ./model/updt/unet_jacc_N2.h5
# 1/1 [==============================] - 0s 303ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 408ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 0s 428ms/step
# ./model/updt/unet_jacc_N1.h5
# 1/1 [==============================] - 0s 295ms/step
# ./model/updt/unet_jacc_N2.h5
# 1/1 [==============================] - 0s 304ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 296ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 0s 303ms/step
# ./model/updt/unet_jacc_N1.h5
# 1/1 [==============================] - 0s 314ms/step
# ./model/updt/unet_jacc_N2.h5
# 1/1 [==============================] - 0s 305ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 306ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 0s 289ms/step
# ./model/updt/unet_jacc_N1.h5
# 1/1 [==============================] - 0s 300ms/step
# ./model/updt/unet_jacc_N2.h5
# 1/1 [==============================] - 0s 306ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 306ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 0s 295ms/step
# ./model/updt/unet_jacc_N1.h5
# 1/1 [==============================] - 0s 300ms/step
# ./model/updt/unet_jacc_N2.h5
# 1/1 [==============================] - 0s 426ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 293ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 0s 300ms/step
# ./model/updt/unet_jacc_N1.h5
# 1/1 [==============================] - 0s 300ms/step
# ./model/updt/unet_jacc_N2.h5
# 1/1 [==============================] - 0s 297ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 287ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 0s 294ms/step
# ./model/updt/unet_jacc_N1.h5
# 1/1 [==============================] - 0s 304ms/step
# ./model/updt/unet_jacc_N2.h5
# 1/1 [==============================] - 0s 304ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 302ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 0s 455ms/step
# ./model/updt/unet_jacc_N1.h5
# 1/1 [==============================] - 0s 302ms/step
# ./model/updt/unet_jacc_N2.h5
# 1/1 [==============================] - 0s 297ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 296ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 0s 296ms/step
# ./model/updt/unet_jacc_N1.h5
# 1/1 [==============================] - 0s 303ms/step
# ./model/updt/unet_jacc_N2.h5
# 1/1 [==============================] - 0s 302ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 301ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 0s 293ms/step
# ./model/updt/unet_jacc_N1.h5
# 1/1 [==============================] - 0s 306ms/step
# ./model/updt/unet_jacc_N2.h5
# 1/1 [==============================] - 0s 307ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 299ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 0s 290ms/step
# ./model/updt/unet_jacc_N1.h5
# 1/1 [==============================] - 0s 298ms/step
# ./model/updt/unet_jacc_N2.h5
# 1/1 [==============================] - 0s 299ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 304ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 0s 294ms/step
# ./model/updt/unet_jacc_N1.h5
# 1/1 [==============================] - 0s 300ms/step
# ./model/updt/unet_jacc_N2.h5
# 1/1 [==============================] - 0s 421ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 299ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 0s 286ms/step
# ./model/updt/unet_jacc_N1.h5
# 1/1 [==============================] - 0s 307ms/step
# ./model/updt/unet_jacc_N2.h5
# 1/1 [==============================] - 0s 295ms/step
# ./model/updt/unet_jacc_N3.h5
# 1/1 [==============================] - 0s 307ms/step
# ./model/updt/unet_jacc_N5.h5
# 1/1 [==============================] - 0s 423ms/step
