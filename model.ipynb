# %% [markdown]
# # Importing Depends

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import cv2
import os
import keras
from glob import glob
import tensorflow as tf
from keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger

# %%
gpus = tf.config.list_physical_devices('GPU')

for i in gpus:
    i = tf.config.experimental.set_memory_growth(i, True)

# %%
batch_size = 2
lr = 1e-4
height = 1024//4
width = 1280//4

# %%
def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(num_filters, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    return x

# %%
def encoder_block(inputs, num_filters):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

# %%
def decoder_block(inputs, skip, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding='same')(inputs)
    x = Concatenate()([x, skip])
    x = conv_block(x, num_filters)
    return x

# %%
def build_unet(input_shape):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    b1 = conv_block(p4, 1024)
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    outputs = Conv2D(1, 1, padding = 'same', activation='sigmoid')(d4)
    model = Model(inputs, outputs, name='UNET')
    return model

# %%
def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (width, height))
    x = x/255.0
    return x

# %%
def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (width, height))
    x = x/255.0
    x = np.expand_dims(x, axis=-1)
    return x

# %%
def convert_to_binary(image_path : str):
    image = cv2.imread(image_path,0)
    numpy_image = np.array([[255 if pixel == 29 else 0 for pixel in row]for row in image])
    return numpy_image.astype(np.uint8)

# %%
def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y
    x, y = tf.numpy_function(_parse, [x, y], [tf.float64, tf.float64])
    x.set_shape([height, width, 3])
    y.set_shape([height, width, 1])

    return x, y

# %%
def tf_dataset(x, y, batch=16):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.map(tf_parse, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

# %% [markdown]
# # Driver Code

# %%
train_path = './train/'

files_dir = os.path.join('files')
model_file = os.path.join('./model/', 'unet.h5')
log_file = os.path.join('./log/', 'log.csv')

# %%
X = glob(os.path.join(train_path, 'frames', '*'))
y = glob(os.path.join(train_path, 'labels_1', '*'))

# %%
from sklearn.model_selection import train_test_split

train_x, val_x, train_y, val_y = train_test_split(X, y, train_size=0.8, shuffle=False, random_state=27)

# %%
train_x
# Out:
# ['./train/frames\\frame000_seq_1.png',
#  './train/frames\\frame000_seq_10.png',
#  './train/frames\\frame000_seq_11.png',
#  './train/frames\\frame000_seq_12.png',
#  './train/frames\\frame000_seq_13.png',
#  './train/frames\\frame000_seq_14.png',
#  './train/frames\\frame000_seq_15.png',
#  './train/frames\\frame000_seq_16.png',
#  './train/frames\\frame000_seq_2.png',
#  './train/frames\\frame000_seq_3.png',
#  './train/frames\\frame000_seq_4.png',
#  './train/frames\\frame000_seq_5.png',
#  './train/frames\\frame000_seq_6.png',
#  './train/frames\\frame000_seq_7.png',
#  './train/frames\\frame000_seq_9.png',
#  './train/frames\\frame001_seq_1.png',
#  './train/frames\\frame001_seq_10.png',
#  './train/frames\\frame001_seq_11.png',
#  './train/frames\\frame001_seq_12.png',
#  './train/frames\\frame001_seq_13.png',
#  './train/frames\\frame001_seq_14.png',
#  './train/frames\\frame001_seq_15.png',
#  './train/frames\\frame001_seq_16.png',
#  './train/frames\\frame001_seq_2.png',
#  './train/frames\\frame001_seq_3.png',
#  './train/frames\\frame001_seq_4.png',
#  './train/frames\\frame001_seq_5.png',
#  './train/frames\\frame001_seq_6.png',
#  './train/frames\\frame001_seq_7.png',
#  './train/frames\\frame001_seq_9.png',
#  './train/frames\\frame002_seq_1.png',
#  './train/frames\\frame002_seq_10.png',
#  './train/frames\\frame002_seq_11.png',
#  './train/frames\\frame002_seq_12.png',
#  './train/frames\\frame002_seq_13.png',
#  './train/frames\\frame002_seq_14.png',
#  './train/frames\\frame002_seq_15.png',
#  './train/frames\\frame002_seq_16.png',
#  './train/frames\\frame002_seq_2.png',
#  './train/frames\\frame002_seq_3.png',
#  './train/frames\\frame002_seq_4.png',
#  './train/frames\\frame002_seq_5.png',
#  './train/frames\\frame002_seq_6.png',
#  './train/frames\\frame002_seq_7.png',
#  './train/frames\\frame002_seq_9.png',
#  './train/frames\\frame003_seq_1.png',
#  './train/frames\\frame003_seq_10.png',
#  './train/frames\\frame003_seq_11.png',
#  './train/frames\\frame003_seq_12.png',
#  './train/frames\\frame003_seq_13.png',
#  './train/frames\\frame003_seq_14.png',
#  './train/frames\\frame003_seq_15.png',
#  './train/frames\\frame003_seq_16.png',
#  './train/frames\\frame003_seq_2.png',
#  './train/frames\\frame003_seq_3.png',
#  './train/frames\\frame003_seq_4.png',
#  './train/frames\\frame003_seq_5.png',
#  './train/frames\\frame003_seq_6.png',
#  './train/frames\\frame003_seq_7.png',
#  './train/frames\\frame003_seq_9.png',
#  './train/frames\\frame004_seq_1.png',
#  './train/frames\\frame004_seq_10.png',
#  './train/frames\\frame004_seq_11.png',
#  './train/frames\\frame004_seq_12.png',
#  './train/frames\\frame004_seq_13.png',
#  './train/frames\\frame004_seq_14.png',
#  './train/frames\\frame004_seq_15.png',
#  './train/frames\\frame004_seq_16.png',
#  './train/frames\\frame004_seq_2.png',
#  './train/frames\\frame004_seq_3.png',
#  './train/frames\\frame004_seq_4.png',
#  './train/frames\\frame004_seq_5.png',
#  './train/frames\\frame004_seq_6.png',
#  './train/frames\\frame004_seq_7.png',
#  './train/frames\\frame004_seq_9.png',
#  './train/frames\\frame005_seq_1.png',
#  './train/frames\\frame005_seq_10.png',
#  './train/frames\\frame005_seq_11.png',
#  './train/frames\\frame005_seq_12.png',
#  './train/frames\\frame005_seq_13.png',
#  './train/frames\\frame005_seq_14.png',
#  './train/frames\\frame005_seq_15.png',
#  './train/frames\\frame005_seq_16.png',
#  './train/frames\\frame005_seq_2.png',
#  './train/frames\\frame005_seq_3.png',
#  './train/frames\\frame005_seq_4.png',
#  './train/frames\\frame005_seq_5.png',
#  './train/frames\\frame005_seq_6.png',
#  './train/frames\\frame005_seq_7.png',
#  './train/frames\\frame005_seq_9.png',
#  './train/frames\\frame006_seq_1.png',
#  './train/frames\\frame006_seq_10.png',
#  './train/frames\\frame006_seq_11.png',
#  './train/frames\\frame006_seq_12.png',
#  './train/frames\\frame006_seq_13.png',
#  './train/frames\\frame006_seq_14.png',
#  './train/frames\\frame006_seq_15.png',
#  './train/frames\\frame006_seq_16.png',
#  './train/frames\\frame006_seq_2.png',
#  './train/frames\\frame006_seq_3.png',
#  './train/frames\\frame006_seq_4.png',
#  './train/frames\\frame006_seq_5.png',
#  './train/frames\\frame006_seq_6.png',
#  './train/frames\\frame006_seq_7.png',
#  './train/frames\\frame006_seq_9.png',
#  './train/frames\\frame007_seq_1.png',
#  './train/frames\\frame007_seq_10.png',
#  './train/frames\\frame007_seq_11.png',
#  './train/frames\\frame007_seq_12.png',
#  './train/frames\\frame007_seq_13.png',
#  './train/frames\\frame007_seq_14.png',
#  './train/frames\\frame007_seq_15.png',
#  './train/frames\\frame007_seq_16.png',
#  './train/frames\\frame007_seq_2.png',
#  './train/frames\\frame007_seq_3.png',
#  './train/frames\\frame007_seq_4.png',
#  './train/frames\\frame007_seq_5.png',
#  './train/frames\\frame007_seq_6.png',
#  './train/frames\\frame007_seq_7.png',
#  './train/frames\\frame007_seq_9.png',
#  './train/frames\\frame008_seq_1.png',
#  './train/frames\\frame008_seq_10.png',
#  './train/frames\\frame008_seq_11.png',
#  './train/frames\\frame008_seq_12.png',
#  './train/frames\\frame008_seq_13.png',
#  './train/frames\\frame008_seq_14.png',
#  './train/frames\\frame008_seq_15.png',
#  './train/frames\\frame008_seq_16.png',
#  './train/frames\\frame008_seq_2.png',
#  './train/frames\\frame008_seq_3.png',
#  './train/frames\\frame008_seq_4.png',
#  './train/frames\\frame008_seq_5.png',
#  './train/frames\\frame008_seq_6.png',
#  './train/frames\\frame008_seq_7.png',
#  './train/frames\\frame008_seq_9.png',
#  './train/frames\\frame009_seq_1.png',
#  './train/frames\\frame009_seq_10.png',
#  './train/frames\\frame009_seq_11.png',
#  './train/frames\\frame009_seq_12.png',
#  './train/frames\\frame009_seq_13.png',
#  './train/frames\\frame009_seq_14.png',
#  './train/frames\\frame009_seq_15.png',
#  './train/frames\\frame009_seq_16.png',
#  './train/frames\\frame009_seq_2.png',
#  './train/frames\\frame009_seq_3.png',
#  './train/frames\\frame009_seq_4.png',
#  './train/frames\\frame009_seq_5.png',
#  './train/frames\\frame009_seq_6.png',
#  './train/frames\\frame009_seq_7.png',
#  './train/frames\\frame009_seq_9.png',
#  './train/frames\\frame010_seq_1.png',
#  './train/frames\\frame010_seq_10.png',
#  './train/frames\\frame010_seq_11.png',
#  './train/frames\\frame010_seq_12.png',
#  './train/frames\\frame010_seq_13.png',
#  './train/frames\\frame010_seq_14.png',
#  './train/frames\\frame010_seq_15.png',
#  './train/frames\\frame010_seq_16.png',
#  './train/frames\\frame010_seq_2.png',
#  './train/frames\\frame010_seq_3.png',
#  './train/frames\\frame010_seq_4.png',
#  './train/frames\\frame010_seq_5.png',
#  './train/frames\\frame010_seq_6.png',
#  './train/frames\\frame010_seq_7.png',
#  './train/frames\\frame010_seq_9.png',
#  './train/frames\\frame011_seq_1.png',
#  './train/frames\\frame011_seq_10.png',
#  './train/frames\\frame011_seq_11.png',
#  './train/frames\\frame011_seq_12.png',
#  './train/frames\\frame011_seq_13.png',
#  './train/frames\\frame011_seq_14.png',
#  './train/frames\\frame011_seq_15.png',
#  './train/frames\\frame011_seq_16.png',
#  './train/frames\\frame011_seq_2.png',
#  './train/frames\\frame011_seq_3.png',
#  './train/frames\\frame011_seq_4.png',
#  './train/frames\\frame011_seq_5.png',
#  './train/frames\\frame011_seq_6.png',
#  './train/frames\\frame011_seq_7.png',
#  './train/frames\\frame011_seq_9.png',
#  './train/frames\\frame012_seq_1.png',
#  './train/frames\\frame012_seq_10.png',
#  './train/frames\\frame012_seq_11.png',
#  './train/frames\\frame012_seq_12.png',
#  './train/frames\\frame012_seq_13.png',
#  './train/frames\\frame012_seq_14.png',
#  './train/frames\\frame012_seq_15.png',
#  './train/frames\\frame012_seq_16.png',
#  './train/frames\\frame012_seq_2.png',
#  './train/frames\\frame012_seq_3.png',
#  './train/frames\\frame012_seq_4.png',
#  './train/frames\\frame012_seq_5.png',
#  './train/frames\\frame012_seq_6.png',
#  './train/frames\\frame012_seq_7.png',
#  './train/frames\\frame012_seq_9.png',
#  './train/frames\\frame013_seq_1.png',
#  './train/frames\\frame013_seq_10.png',
#  './train/frames\\frame013_seq_11.png',
#  './train/frames\\frame013_seq_12.png',
#  './train/frames\\frame013_seq_13.png',
#  './train/frames\\frame013_seq_14.png',
#  './train/frames\\frame013_seq_15.png',
#  './train/frames\\frame013_seq_16.png',
#  './train/frames\\frame013_seq_2.png',
#  './train/frames\\frame013_seq_3.png',
#  './train/frames\\frame013_seq_4.png',
#  './train/frames\\frame013_seq_5.png',
#  './train/frames\\frame013_seq_6.png',
#  './train/frames\\frame013_seq_7.png',
#  './train/frames\\frame013_seq_9.png',
#  './train/frames\\frame014_seq_1.png',
#  './train/frames\\frame014_seq_10.png',
#  './train/frames\\frame014_seq_11.png',
#  './train/frames\\frame014_seq_12.png',
#  './train/frames\\frame014_seq_13.png',
#  './train/frames\\frame014_seq_14.png',
#  './train/frames\\frame014_seq_15.png',
#  './train/frames\\frame014_seq_16.png',
#  './train/frames\\frame014_seq_2.png',
#  './train/frames\\frame014_seq_3.png',
#  './train/frames\\frame014_seq_4.png',
#  './train/frames\\frame014_seq_5.png',
#  './train/frames\\frame014_seq_6.png',
#  './train/frames\\frame014_seq_7.png',
#  './train/frames\\frame014_seq_9.png',
#  './train/frames\\frame015_seq_1.png',
#  './train/frames\\frame015_seq_10.png',
#  './train/frames\\frame015_seq_11.png',
#  './train/frames\\frame015_seq_12.png',
#  './train/frames\\frame015_seq_13.png',
#  './train/frames\\frame015_seq_14.png',
#  './train/frames\\frame015_seq_15.png',
#  './train/frames\\frame015_seq_16.png',
#  './train/frames\\frame015_seq_2.png',
#  './train/frames\\frame015_seq_3.png',
#  './train/frames\\frame015_seq_4.png',
#  './train/frames\\frame015_seq_5.png',
#  './train/frames\\frame015_seq_6.png',
#  './train/frames\\frame015_seq_7.png',
#  './train/frames\\frame015_seq_9.png',
#  './train/frames\\frame016_seq_1.png',
#  './train/frames\\frame016_seq_10.png',
#  './train/frames\\frame016_seq_11.png',
#  './train/frames\\frame016_seq_12.png',
#  './train/frames\\frame016_seq_13.png',
#  './train/frames\\frame016_seq_14.png',
#  './train/frames\\frame016_seq_15.png',
#  './train/frames\\frame016_seq_16.png',
#  './train/frames\\frame016_seq_2.png',
#  './train/frames\\frame016_seq_3.png',
#  './train/frames\\frame016_seq_4.png',
#  './train/frames\\frame016_seq_5.png',
#  './train/frames\\frame016_seq_6.png',
#  './train/frames\\frame016_seq_7.png',
#  './train/frames\\frame016_seq_9.png',
#  './train/frames\\frame017_seq_1.png',
#  './train/frames\\frame017_seq_10.png',
#  './train/frames\\frame017_seq_11.png',
#  './train/frames\\frame017_seq_12.png',
#  './train/frames\\frame017_seq_13.png',
#  './train/frames\\frame017_seq_14.png',
#  './train/frames\\frame017_seq_15.png',
#  './train/frames\\frame017_seq_16.png',
#  './train/frames\\frame017_seq_2.png',
#  './train/frames\\frame017_seq_3.png',
#  './train/frames\\frame017_seq_4.png',
#  './train/frames\\frame017_seq_5.png',
#  './train/frames\\frame017_seq_6.png',
#  './train/frames\\frame017_seq_7.png',
#  './train/frames\\frame017_seq_9.png',
#  './train/frames\\frame018_seq_1.png',
#  './train/frames\\frame018_seq_10.png',
#  './train/frames\\frame018_seq_11.png',
#  './train/frames\\frame018_seq_12.png',
#  './train/frames\\frame018_seq_13.png',
#  './train/frames\\frame018_seq_14.png',
#  './train/frames\\frame018_seq_15.png',
#  './train/frames\\frame018_seq_16.png',
#  './train/frames\\frame018_seq_2.png',
#  './train/frames\\frame018_seq_3.png',
#  './train/frames\\frame018_seq_4.png',
#  './train/frames\\frame018_seq_5.png',
#  './train/frames\\frame018_seq_6.png',
#  './train/frames\\frame018_seq_7.png',
#  './train/frames\\frame018_seq_9.png',
#  './train/frames\\frame019_seq_1.png',
#  './train/frames\\frame019_seq_10.png',
#  './train/frames\\frame019_seq_11.png',
#  './train/frames\\frame019_seq_12.png',
#  './train/frames\\frame019_seq_13.png',
#  './train/frames\\frame019_seq_14.png',
#  './train/frames\\frame019_seq_15.png',
#  './train/frames\\frame019_seq_16.png',
#  './train/frames\\frame019_seq_2.png',
#  './train/frames\\frame019_seq_3.png',
#  './train/frames\\frame019_seq_4.png',
#  './train/frames\\frame019_seq_5.png',
#  './train/frames\\frame019_seq_6.png',
#  './train/frames\\frame019_seq_7.png',
#  './train/frames\\frame019_seq_9.png',
#  './train/frames\\frame020_seq_1.png',
#  './train/frames\\frame020_seq_10.png',
#  './train/frames\\frame020_seq_11.png',
#  './train/frames\\frame020_seq_12.png',
#  './train/frames\\frame020_seq_13.png',
#  './train/frames\\frame020_seq_14.png',
#  './train/frames\\frame020_seq_15.png',
#  './train/frames\\frame020_seq_16.png',
#  './train/frames\\frame020_seq_2.png',
#  './train/frames\\frame020_seq_3.png',
#  './train/frames\\frame020_seq_4.png',
#  './train/frames\\frame020_seq_5.png',
#  './train/frames\\frame020_seq_6.png',
#  './train/frames\\frame020_seq_7.png',
#  './train/frames\\frame020_seq_9.png',
#  './train/frames\\frame021_seq_1.png',
#  './train/frames\\frame021_seq_10.png',
#  './train/frames\\frame021_seq_11.png',
#  './train/frames\\frame021_seq_12.png',
#  './train/frames\\frame021_seq_13.png',
#  './train/frames\\frame021_seq_14.png',
#  './train/frames\\frame021_seq_15.png',
#  './train/frames\\frame021_seq_16.png',
#  './train/frames\\frame021_seq_2.png',
#  './train/frames\\frame021_seq_3.png',
#  './train/frames\\frame021_seq_4.png',
#  './train/frames\\frame021_seq_5.png',
#  './train/frames\\frame021_seq_6.png',
#  './train/frames\\frame021_seq_7.png',
#  './train/frames\\frame021_seq_9.png',
#  './train/frames\\frame022_seq_1.png',
#  './train/frames\\frame022_seq_10.png',
#  './train/frames\\frame022_seq_11.png',
#  './train/frames\\frame022_seq_12.png',
#  './train/frames\\frame022_seq_13.png',
#  './train/frames\\frame022_seq_14.png',
#  './train/frames\\frame022_seq_15.png',
#  './train/frames\\frame022_seq_16.png',
#  './train/frames\\frame022_seq_2.png',
#  './train/frames\\frame022_seq_3.png',
#  './train/frames\\frame022_seq_4.png',
#  './train/frames\\frame022_seq_5.png',
#  './train/frames\\frame022_seq_6.png',
#  './train/frames\\frame022_seq_7.png',
#  './train/frames\\frame022_seq_9.png',
#  './train/frames\\frame023_seq_1.png',
#  './train/frames\\frame023_seq_10.png',
#  './train/frames\\frame023_seq_11.png',
#  './train/frames\\frame023_seq_12.png',
#  './train/frames\\frame023_seq_13.png',
#  './train/frames\\frame023_seq_14.png',
#  './train/frames\\frame023_seq_15.png',
#  './train/frames\\frame023_seq_16.png',
#  './train/frames\\frame023_seq_2.png',
#  './train/frames\\frame023_seq_3.png',
#  './train/frames\\frame023_seq_4.png',
#  './train/frames\\frame023_seq_5.png',
#  './train/frames\\frame023_seq_6.png',
#  './train/frames\\frame023_seq_7.png',
#  './train/frames\\frame023_seq_9.png',
#  './train/frames\\frame024_seq_1.png',
#  './train/frames\\frame024_seq_10.png',
#  './train/frames\\frame024_seq_11.png',
#  './train/frames\\frame024_seq_12.png',
#  './train/frames\\frame024_seq_13.png',
#  './train/frames\\frame024_seq_14.png',
#  './train/frames\\frame024_seq_15.png',
#  './train/frames\\frame024_seq_16.png',
#  './train/frames\\frame024_seq_2.png',
#  './train/frames\\frame024_seq_3.png',
#  './train/frames\\frame024_seq_4.png',
#  './train/frames\\frame024_seq_5.png',
#  './train/frames\\frame024_seq_6.png',
#  './train/frames\\frame024_seq_7.png',
#  './train/frames\\frame024_seq_9.png',
#  './train/frames\\frame025_seq_1.png',
#  './train/frames\\frame025_seq_10.png',
#  './train/frames\\frame025_seq_11.png',
#  './train/frames\\frame025_seq_12.png',
#  './train/frames\\frame025_seq_13.png',
#  './train/frames\\frame025_seq_14.png',
#  './train/frames\\frame025_seq_15.png',
#  './train/frames\\frame025_seq_16.png',
#  './train/frames\\frame025_seq_2.png',
#  './train/frames\\frame025_seq_3.png',
#  './train/frames\\frame025_seq_4.png',
#  './train/frames\\frame025_seq_5.png',
#  './train/frames\\frame025_seq_6.png',
#  './train/frames\\frame025_seq_7.png',
#  './train/frames\\frame025_seq_9.png',
#  './train/frames\\frame026_seq_1.png',
#  './train/frames\\frame026_seq_10.png',
#  './train/frames\\frame026_seq_11.png',
#  './train/frames\\frame026_seq_12.png',
#  './train/frames\\frame026_seq_13.png',
#  './train/frames\\frame026_seq_14.png',
#  './train/frames\\frame026_seq_15.png',
#  './train/frames\\frame026_seq_16.png',
#  './train/frames\\frame026_seq_2.png',
#  './train/frames\\frame026_seq_3.png',
#  './train/frames\\frame026_seq_4.png',
#  './train/frames\\frame026_seq_5.png',
#  './train/frames\\frame026_seq_6.png',
#  './train/frames\\frame026_seq_7.png',
#  './train/frames\\frame026_seq_9.png',
#  './train/frames\\frame027_seq_1.png',
#  './train/frames\\frame027_seq_10.png',
#  './train/frames\\frame027_seq_11.png',
#  './train/frames\\frame027_seq_12.png',
#  './train/frames\\frame027_seq_13.png',
#  './train/frames\\frame027_seq_14.png',
#  './train/frames\\frame027_seq_15.png',
#  './train/frames\\frame027_seq_16.png',
#  './train/frames\\frame027_seq_2.png',
#  './train/frames\\frame027_seq_3.png',
#  './train/frames\\frame027_seq_4.png',
#  './train/frames\\frame027_seq_5.png',
#  './train/frames\\frame027_seq_6.png',
#  './train/frames\\frame027_seq_7.png',
#  './train/frames\\frame027_seq_9.png',
#  './train/frames\\frame028_seq_1.png',
#  './train/frames\\frame028_seq_10.png',
#  './train/frames\\frame028_seq_11.png',
#  './train/frames\\frame028_seq_12.png',
#  './train/frames\\frame028_seq_13.png',
#  './train/frames\\frame028_seq_14.png',
#  './train/frames\\frame028_seq_15.png',
#  './train/frames\\frame028_seq_16.png',
#  './train/frames\\frame028_seq_2.png',
#  './train/frames\\frame028_seq_3.png',
#  './train/frames\\frame028_seq_4.png',
#  './train/frames\\frame028_seq_5.png',
#  './train/frames\\frame028_seq_6.png',
#  './train/frames\\frame028_seq_7.png',
#  './train/frames\\frame028_seq_9.png',
#  './train/frames\\frame029_seq_1.png',
#  './train/frames\\frame029_seq_10.png',
#  './train/frames\\frame029_seq_11.png',
#  './train/frames\\frame029_seq_12.png',
#  './train/frames\\frame029_seq_13.png',
#  './train/frames\\frame029_seq_14.png',
#  './train/frames\\frame029_seq_15.png',
#  './train/frames\\frame029_seq_16.png',
#  './train/frames\\frame029_seq_2.png',
#  './train/frames\\frame029_seq_3.png',
#  './train/frames\\frame029_seq_4.png',
#  './train/frames\\frame029_seq_5.png',
#  './train/frames\\frame029_seq_6.png',
#  './train/frames\\frame029_seq_7.png',
#  './train/frames\\frame029_seq_9.png',
#  './train/frames\\frame030_seq_1.png',
#  './train/frames\\frame030_seq_10.png',
#  './train/frames\\frame030_seq_11.png',
#  './train/frames\\frame030_seq_12.png',
#  './train/frames\\frame030_seq_13.png',
#  './train/frames\\frame030_seq_14.png',
#  './train/frames\\frame030_seq_15.png',
#  './train/frames\\frame030_seq_16.png',
#  './train/frames\\frame030_seq_2.png',
#  './train/frames\\frame030_seq_3.png',
#  './train/frames\\frame030_seq_4.png',
#  './train/frames\\frame030_seq_5.png',
#  './train/frames\\frame030_seq_6.png',
#  './train/frames\\frame030_seq_7.png',
#  './train/frames\\frame030_seq_9.png',
#  './train/frames\\frame031_seq_1.png',
#  './train/frames\\frame031_seq_10.png',
#  './train/frames\\frame031_seq_11.png',
#  './train/frames\\frame031_seq_12.png',
#  './train/frames\\frame031_seq_13.png',
#  './train/frames\\frame031_seq_14.png',
#  './train/frames\\frame031_seq_15.png',
#  './train/frames\\frame031_seq_16.png',
#  './train/frames\\frame031_seq_2.png',
#  './train/frames\\frame031_seq_3.png',
#  './train/frames\\frame031_seq_4.png',
#  './train/frames\\frame031_seq_5.png',
#  './train/frames\\frame031_seq_6.png',
#  './train/frames\\frame031_seq_7.png',
#  './train/frames\\frame031_seq_9.png',
#  './train/frames\\frame032_seq_1.png',
#  './train/frames\\frame032_seq_10.png',
#  './train/frames\\frame032_seq_11.png',
#  './train/frames\\frame032_seq_12.png',
#  './train/frames\\frame032_seq_13.png',
#  './train/frames\\frame032_seq_14.png',
#  './train/frames\\frame032_seq_15.png',
#  './train/frames\\frame032_seq_16.png',
#  './train/frames\\frame032_seq_2.png',
#  './train/frames\\frame032_seq_3.png',
#  './train/frames\\frame032_seq_4.png',
#  './train/frames\\frame032_seq_5.png',
#  './train/frames\\frame032_seq_6.png',
#  './train/frames\\frame032_seq_7.png',
#  './train/frames\\frame032_seq_9.png',
#  './train/frames\\frame033_seq_1.png',
#  './train/frames\\frame033_seq_10.png',
#  './train/frames\\frame033_seq_11.png',
#  './train/frames\\frame033_seq_12.png',
#  './train/frames\\frame033_seq_13.png',
#  './train/frames\\frame033_seq_14.png',
#  './train/frames\\frame033_seq_15.png',
#  './train/frames\\frame033_seq_16.png',
#  './train/frames\\frame033_seq_2.png',
#  './train/frames\\frame033_seq_3.png',
#  './train/frames\\frame033_seq_4.png',
#  './train/frames\\frame033_seq_5.png',
#  './train/frames\\frame033_seq_6.png',
#  './train/frames\\frame033_seq_7.png',
#  './train/frames\\frame033_seq_9.png',
#  './train/frames\\frame034_seq_1.png',
#  './train/frames\\frame034_seq_10.png',
#  './train/frames\\frame034_seq_11.png',
#  './train/frames\\frame034_seq_12.png',
#  './train/frames\\frame034_seq_13.png',
#  './train/frames\\frame034_seq_14.png',
#  './train/frames\\frame034_seq_15.png',
#  './train/frames\\frame034_seq_16.png',
#  './train/frames\\frame034_seq_2.png',
#  './train/frames\\frame034_seq_3.png',
#  './train/frames\\frame034_seq_4.png',
#  './train/frames\\frame034_seq_5.png',
#  './train/frames\\frame034_seq_6.png',
#  './train/frames\\frame034_seq_7.png',
#  './train/frames\\frame034_seq_9.png',
#  './train/frames\\frame035_seq_1.png',
#  './train/frames\\frame035_seq_10.png',
#  './train/frames\\frame035_seq_11.png',
#  './train/frames\\frame035_seq_12.png',
#  './train/frames\\frame035_seq_13.png',
#  './train/frames\\frame035_seq_14.png',
#  './train/frames\\frame035_seq_15.png',
#  './train/frames\\frame035_seq_16.png',
#  './train/frames\\frame035_seq_2.png',
#  './train/frames\\frame035_seq_3.png',
#  './train/frames\\frame035_seq_4.png',
#  './train/frames\\frame035_seq_5.png',
#  './train/frames\\frame035_seq_6.png',
#  './train/frames\\frame035_seq_7.png',
#  './train/frames\\frame035_seq_9.png',
#  './train/frames\\frame036_seq_1.png',
#  './train/frames\\frame036_seq_10.png',
#  './train/frames\\frame036_seq_11.png',
#  './train/frames\\frame036_seq_12.png',
#  './train/frames\\frame036_seq_13.png',
#  './train/frames\\frame036_seq_14.png',
#  './train/frames\\frame036_seq_15.png',
#  './train/frames\\frame036_seq_16.png',
#  './train/frames\\frame036_seq_2.png',
#  './train/frames\\frame036_seq_3.png',
#  './train/frames\\frame036_seq_4.png',
#  './train/frames\\frame036_seq_5.png',
#  './train/frames\\frame036_seq_6.png',
#  './train/frames\\frame036_seq_7.png',
#  './train/frames\\frame036_seq_9.png',
#  './train/frames\\frame037_seq_1.png',
#  './train/frames\\frame037_seq_10.png',
#  './train/frames\\frame037_seq_11.png',
#  './train/frames\\frame037_seq_12.png',
#  './train/frames\\frame037_seq_13.png',
#  './train/frames\\frame037_seq_14.png',
#  './train/frames\\frame037_seq_15.png',
#  './train/frames\\frame037_seq_16.png',
#  './train/frames\\frame037_seq_2.png',
#  './train/frames\\frame037_seq_3.png',
#  './train/frames\\frame037_seq_4.png',
#  './train/frames\\frame037_seq_5.png',
#  './train/frames\\frame037_seq_6.png',
#  './train/frames\\frame037_seq_7.png',
#  './train/frames\\frame037_seq_9.png',
#  './train/frames\\frame038_seq_1.png',
#  './train/frames\\frame038_seq_10.png',
#  './train/frames\\frame038_seq_11.png',
#  './train/frames\\frame038_seq_12.png',
#  './train/frames\\frame038_seq_13.png',
#  './train/frames\\frame038_seq_14.png',
#  './train/frames\\frame038_seq_15.png',
#  './train/frames\\frame038_seq_16.png',
#  './train/frames\\frame038_seq_2.png',
#  './train/frames\\frame038_seq_3.png',
#  './train/frames\\frame038_seq_4.png',
#  './train/frames\\frame038_seq_5.png',
#  './train/frames\\frame038_seq_6.png',
#  './train/frames\\frame038_seq_7.png',
#  './train/frames\\frame038_seq_9.png',
#  './train/frames\\frame039_seq_1.png',
#  './train/frames\\frame039_seq_10.png',
#  './train/frames\\frame039_seq_11.png',
#  './train/frames\\frame039_seq_12.png',
#  './train/frames\\frame039_seq_13.png',
#  './train/frames\\frame039_seq_14.png',
#  './train/frames\\frame039_seq_15.png',
#  './train/frames\\frame039_seq_16.png',
#  './train/frames\\frame039_seq_2.png',
#  './train/frames\\frame039_seq_3.png',
#  './train/frames\\frame039_seq_4.png',
#  './train/frames\\frame039_seq_5.png',
#  './train/frames\\frame039_seq_6.png',
#  './train/frames\\frame039_seq_7.png',
#  './train/frames\\frame039_seq_9.png',
#  './train/frames\\frame040_seq_1.png',
#  './train/frames\\frame040_seq_10.png',
#  './train/frames\\frame040_seq_11.png',
#  './train/frames\\frame040_seq_12.png',
#  './train/frames\\frame040_seq_13.png',
#  './train/frames\\frame040_seq_14.png',
#  './train/frames\\frame040_seq_15.png',
#  './train/frames\\frame040_seq_16.png',
#  './train/frames\\frame040_seq_2.png',
#  './train/frames\\frame040_seq_3.png',
#  './train/frames\\frame040_seq_4.png',
#  './train/frames\\frame040_seq_5.png',
#  './train/frames\\frame040_seq_6.png',
#  './train/frames\\frame040_seq_7.png',
#  './train/frames\\frame040_seq_9.png',
#  './train/frames\\frame041_seq_1.png',
#  './train/frames\\frame041_seq_10.png',
#  './train/frames\\frame041_seq_11.png',
#  './train/frames\\frame041_seq_12.png',
#  './train/frames\\frame041_seq_13.png',
#  './train/frames\\frame041_seq_14.png',
#  './train/frames\\frame041_seq_15.png',
#  './train/frames\\frame041_seq_16.png',
#  './train/frames\\frame041_seq_2.png',
#  './train/frames\\frame041_seq_3.png',
#  './train/frames\\frame041_seq_4.png',
#  './train/frames\\frame041_seq_5.png',
#  './train/frames\\frame041_seq_6.png',
#  './train/frames\\frame041_seq_7.png',
#  './train/frames\\frame041_seq_9.png',
#  './train/frames\\frame042_seq_1.png',
#  './train/frames\\frame042_seq_10.png',
#  './train/frames\\frame042_seq_11.png',
#  './train/frames\\frame042_seq_12.png',
#  './train/frames\\frame042_seq_13.png',
#  './train/frames\\frame042_seq_14.png',
#  './train/frames\\frame042_seq_15.png',
#  './train/frames\\frame042_seq_16.png',
#  './train/frames\\frame042_seq_2.png',
#  './train/frames\\frame042_seq_3.png',
#  './train/frames\\frame042_seq_4.png',
#  './train/frames\\frame042_seq_5.png',
#  './train/frames\\frame042_seq_6.png',
#  './train/frames\\frame042_seq_7.png',
#  './train/frames\\frame042_seq_9.png',
#  './train/frames\\frame043_seq_1.png',
#  './train/frames\\frame043_seq_10.png',
#  './train/frames\\frame043_seq_11.png',
#  './train/frames\\frame043_seq_12.png',
#  './train/frames\\frame043_seq_13.png',
#  './train/frames\\frame043_seq_14.png',
#  './train/frames\\frame043_seq_15.png',
#  './train/frames\\frame043_seq_16.png',
#  './train/frames\\frame043_seq_2.png',
#  './train/frames\\frame043_seq_3.png',
#  './train/frames\\frame043_seq_4.png',
#  './train/frames\\frame043_seq_5.png',
#  './train/frames\\frame043_seq_6.png',
#  './train/frames\\frame043_seq_7.png',
#  './train/frames\\frame043_seq_9.png',
#  './train/frames\\frame044_seq_1.png',
#  './train/frames\\frame044_seq_10.png',
#  './train/frames\\frame044_seq_11.png',
#  './train/frames\\frame044_seq_12.png',
#  './train/frames\\frame044_seq_13.png',
#  './train/frames\\frame044_seq_14.png',
#  './train/frames\\frame044_seq_15.png',
#  './train/frames\\frame044_seq_16.png',
#  './train/frames\\frame044_seq_2.png',
#  './train/frames\\frame044_seq_3.png',
#  './train/frames\\frame044_seq_4.png',
#  './train/frames\\frame044_seq_5.png',
#  './train/frames\\frame044_seq_6.png',
#  './train/frames\\frame044_seq_7.png',
#  './train/frames\\frame044_seq_9.png',
#  './train/frames\\frame045_seq_1.png',
#  './train/frames\\frame045_seq_10.png',
#  './train/frames\\frame045_seq_11.png',
#  './train/frames\\frame045_seq_12.png',
#  './train/frames\\frame045_seq_13.png',
#  './train/frames\\frame045_seq_14.png',
#  './train/frames\\frame045_seq_15.png',
#  './train/frames\\frame045_seq_16.png',
#  './train/frames\\frame045_seq_2.png',
#  './train/frames\\frame045_seq_3.png',
#  './train/frames\\frame045_seq_4.png',
#  './train/frames\\frame045_seq_5.png',
#  './train/frames\\frame045_seq_6.png',
#  './train/frames\\frame045_seq_7.png',
#  './train/frames\\frame045_seq_9.png',
#  './train/frames\\frame046_seq_1.png',
#  './train/frames\\frame046_seq_10.png',
#  './train/frames\\frame046_seq_11.png',
#  './train/frames\\frame046_seq_12.png',
#  './train/frames\\frame046_seq_13.png',
#  './train/frames\\frame046_seq_14.png',
#  './train/frames\\frame046_seq_15.png',
#  './train/frames\\frame046_seq_16.png',
#  './train/frames\\frame046_seq_2.png',
#  './train/frames\\frame046_seq_3.png',
#  './train/frames\\frame046_seq_4.png',
#  './train/frames\\frame046_seq_5.png',
#  './train/frames\\frame046_seq_6.png',
#  './train/frames\\frame046_seq_7.png',
#  './train/frames\\frame046_seq_9.png',
#  './train/frames\\frame047_seq_1.png',
#  './train/frames\\frame047_seq_10.png',
#  './train/frames\\frame047_seq_11.png',
#  './train/frames\\frame047_seq_12.png',
#  './train/frames\\frame047_seq_13.png',
#  './train/frames\\frame047_seq_14.png',
#  './train/frames\\frame047_seq_15.png',
#  './train/frames\\frame047_seq_16.png',
#  './train/frames\\frame047_seq_2.png',
#  './train/frames\\frame047_seq_3.png',
#  './train/frames\\frame047_seq_4.png',
#  './train/frames\\frame047_seq_5.png',
#  './train/frames\\frame047_seq_6.png',
#  './train/frames\\frame047_seq_7.png',
#  './train/frames\\frame047_seq_9.png',
#  './train/frames\\frame048_seq_1.png',
#  './train/frames\\frame048_seq_10.png',
#  './train/frames\\frame048_seq_11.png',
#  './train/frames\\frame048_seq_12.png',
#  './train/frames\\frame048_seq_13.png',
#  './train/frames\\frame048_seq_14.png',
#  './train/frames\\frame048_seq_15.png',
#  './train/frames\\frame048_seq_16.png',
#  './train/frames\\frame048_seq_2.png',
#  './train/frames\\frame048_seq_3.png',
#  './train/frames\\frame048_seq_4.png',
#  './train/frames\\frame048_seq_5.png',
#  './train/frames\\frame048_seq_6.png',
#  './train/frames\\frame048_seq_7.png',
#  './train/frames\\frame048_seq_9.png',
#  './train/frames\\frame049_seq_1.png',
#  './train/frames\\frame049_seq_10.png',
#  './train/frames\\frame049_seq_11.png',
#  './train/frames\\frame049_seq_12.png',
#  './train/frames\\frame049_seq_13.png',
#  './train/frames\\frame049_seq_14.png',
#  './train/frames\\frame049_seq_15.png',
#  './train/frames\\frame049_seq_16.png',
#  './train/frames\\frame049_seq_2.png',
#  './train/frames\\frame049_seq_3.png',
#  './train/frames\\frame049_seq_4.png',
#  './train/frames\\frame049_seq_5.png',
#  './train/frames\\frame049_seq_6.png',
#  './train/frames\\frame049_seq_7.png',
#  './train/frames\\frame049_seq_9.png',
#  './train/frames\\frame050_seq_1.png',
#  './train/frames\\frame050_seq_10.png',
#  './train/frames\\frame050_seq_11.png',
#  './train/frames\\frame050_seq_12.png',
#  './train/frames\\frame050_seq_13.png',
#  './train/frames\\frame050_seq_14.png',
#  './train/frames\\frame050_seq_15.png',
#  './train/frames\\frame050_seq_16.png',
#  './train/frames\\frame050_seq_2.png',
#  './train/frames\\frame050_seq_3.png',
#  './train/frames\\frame050_seq_4.png',
#  './train/frames\\frame050_seq_5.png',
#  './train/frames\\frame050_seq_6.png',
#  './train/frames\\frame050_seq_7.png',
#  './train/frames\\frame050_seq_9.png',
#  './train/frames\\frame051_seq_1.png',
#  './train/frames\\frame051_seq_10.png',
#  './train/frames\\frame051_seq_11.png',
#  './train/frames\\frame051_seq_12.png',
#  './train/frames\\frame051_seq_13.png',
#  './train/frames\\frame051_seq_14.png',
#  './train/frames\\frame051_seq_15.png',
#  './train/frames\\frame051_seq_16.png',
#  './train/frames\\frame051_seq_2.png',
#  './train/frames\\frame051_seq_3.png',
#  './train/frames\\frame051_seq_4.png',
#  './train/frames\\frame051_seq_5.png',
#  './train/frames\\frame051_seq_6.png',
#  './train/frames\\frame051_seq_7.png',
#  './train/frames\\frame051_seq_9.png',
#  './train/frames\\frame052_seq_1.png',
#  './train/frames\\frame052_seq_10.png',
#  './train/frames\\frame052_seq_11.png',
#  './train/frames\\frame052_seq_12.png',
#  './train/frames\\frame052_seq_13.png',
#  './train/frames\\frame052_seq_14.png',
#  './train/frames\\frame052_seq_15.png',
#  './train/frames\\frame052_seq_16.png',
#  './train/frames\\frame052_seq_2.png',
#  './train/frames\\frame052_seq_3.png',
#  './train/frames\\frame052_seq_4.png',
#  './train/frames\\frame052_seq_5.png',
#  './train/frames\\frame052_seq_6.png',
#  './train/frames\\frame052_seq_7.png',
#  './train/frames\\frame052_seq_9.png',
#  './train/frames\\frame053_seq_1.png',
#  './train/frames\\frame053_seq_10.png',
#  './train/frames\\frame053_seq_11.png',
#  './train/frames\\frame053_seq_12.png',
#  './train/frames\\frame053_seq_13.png',
#  './train/frames\\frame053_seq_14.png',
#  './train/frames\\frame053_seq_15.png',
#  './train/frames\\frame053_seq_16.png',
#  './train/frames\\frame053_seq_2.png',
#  './train/frames\\frame053_seq_3.png',
#  './train/frames\\frame053_seq_4.png',
#  './train/frames\\frame053_seq_5.png',
#  './train/frames\\frame053_seq_6.png',
#  './train/frames\\frame053_seq_7.png',
#  './train/frames\\frame053_seq_9.png',
#  './train/frames\\frame054_seq_1.png',
#  './train/frames\\frame054_seq_10.png',
#  './train/frames\\frame054_seq_11.png',
#  './train/frames\\frame054_seq_12.png',
#  './train/frames\\frame054_seq_13.png',
#  './train/frames\\frame054_seq_14.png',
#  './train/frames\\frame054_seq_15.png',
#  './train/frames\\frame054_seq_16.png',
#  './train/frames\\frame054_seq_2.png',
#  './train/frames\\frame054_seq_3.png',
#  './train/frames\\frame054_seq_4.png',
#  './train/frames\\frame054_seq_5.png',
#  './train/frames\\frame054_seq_6.png',
#  './train/frames\\frame054_seq_7.png',
#  './train/frames\\frame054_seq_9.png',
#  './train/frames\\frame055_seq_1.png',
#  './train/frames\\frame055_seq_10.png',
#  './train/frames\\frame055_seq_11.png',
#  './train/frames\\frame055_seq_12.png',
#  './train/frames\\frame055_seq_13.png',
#  './train/frames\\frame055_seq_14.png',
#  './train/frames\\frame055_seq_15.png',
#  './train/frames\\frame055_seq_16.png',
#  './train/frames\\frame055_seq_2.png',
#  './train/frames\\frame055_seq_3.png',
#  './train/frames\\frame055_seq_4.png',
#  './train/frames\\frame055_seq_5.png',
#  './train/frames\\frame055_seq_6.png',
#  './train/frames\\frame055_seq_7.png',
#  './train/frames\\frame055_seq_9.png',
#  './train/frames\\frame056_seq_1.png',
#  './train/frames\\frame056_seq_10.png',
#  './train/frames\\frame056_seq_11.png',
#  './train/frames\\frame056_seq_12.png',
#  './train/frames\\frame056_seq_13.png',
#  './train/frames\\frame056_seq_14.png',
#  './train/frames\\frame056_seq_15.png',
#  './train/frames\\frame056_seq_16.png',
#  './train/frames\\frame056_seq_2.png',
#  './train/frames\\frame056_seq_3.png',
#  './train/frames\\frame056_seq_4.png',
#  './train/frames\\frame056_seq_5.png',
#  './train/frames\\frame056_seq_6.png',
#  './train/frames\\frame056_seq_7.png',
#  './train/frames\\frame056_seq_9.png',
#  './train/frames\\frame057_seq_1.png',
#  './train/frames\\frame057_seq_10.png',
#  './train/frames\\frame057_seq_11.png',
#  './train/frames\\frame057_seq_12.png',
#  './train/frames\\frame057_seq_13.png',
#  './train/frames\\frame057_seq_14.png',
#  './train/frames\\frame057_seq_15.png',
#  './train/frames\\frame057_seq_16.png',
#  './train/frames\\frame057_seq_2.png',
#  './train/frames\\frame057_seq_3.png',
#  './train/frames\\frame057_seq_4.png',
#  './train/frames\\frame057_seq_5.png',
#  './train/frames\\frame057_seq_6.png',
#  './train/frames\\frame057_seq_7.png',
#  './train/frames\\frame057_seq_9.png',
#  './train/frames\\frame058_seq_1.png',
#  './train/frames\\frame058_seq_10.png',
#  './train/frames\\frame058_seq_11.png',
#  './train/frames\\frame058_seq_12.png',
#  './train/frames\\frame058_seq_13.png',
#  './train/frames\\frame058_seq_14.png',
#  './train/frames\\frame058_seq_15.png',
#  './train/frames\\frame058_seq_16.png',
#  './train/frames\\frame058_seq_2.png',
#  './train/frames\\frame058_seq_3.png',
#  './train/frames\\frame058_seq_4.png',
#  './train/frames\\frame058_seq_5.png',
#  './train/frames\\frame058_seq_6.png',
#  './train/frames\\frame058_seq_7.png',
#  './train/frames\\frame058_seq_9.png',
#  './train/frames\\frame059_seq_1.png',
#  './train/frames\\frame059_seq_10.png',
#  './train/frames\\frame059_seq_11.png',
#  './train/frames\\frame059_seq_12.png',
#  './train/frames\\frame059_seq_13.png',
#  './train/frames\\frame059_seq_14.png',
#  './train/frames\\frame059_seq_15.png',
#  './train/frames\\frame059_seq_16.png',
#  './train/frames\\frame059_seq_2.png',
#  './train/frames\\frame059_seq_3.png',
#  './train/frames\\frame059_seq_4.png',
#  './train/frames\\frame059_seq_5.png',
#  './train/frames\\frame059_seq_6.png',
#  './train/frames\\frame059_seq_7.png',
#  './train/frames\\frame059_seq_9.png',
#  './train/frames\\frame060_seq_1.png',
#  './train/frames\\frame060_seq_10.png',
#  './train/frames\\frame060_seq_11.png',
#  './train/frames\\frame060_seq_12.png',
#  './train/frames\\frame060_seq_13.png',
#  './train/frames\\frame060_seq_14.png',
#  './train/frames\\frame060_seq_15.png',
#  './train/frames\\frame060_seq_16.png',
#  './train/frames\\frame060_seq_2.png',
#  './train/frames\\frame060_seq_3.png',
#  './train/frames\\frame060_seq_4.png',
#  './train/frames\\frame060_seq_5.png',
#  './train/frames\\frame060_seq_6.png',
#  './train/frames\\frame060_seq_7.png',
#  './train/frames\\frame060_seq_9.png',
#  './train/frames\\frame061_seq_1.png',
#  './train/frames\\frame061_seq_10.png',
#  './train/frames\\frame061_seq_11.png',
#  './train/frames\\frame061_seq_12.png',
#  './train/frames\\frame061_seq_13.png',
#  './train/frames\\frame061_seq_14.png',
#  './train/frames\\frame061_seq_15.png',
#  './train/frames\\frame061_seq_16.png',
#  './train/frames\\frame061_seq_2.png',
#  './train/frames\\frame061_seq_3.png',
#  './train/frames\\frame061_seq_4.png',
#  './train/frames\\frame061_seq_5.png',
#  './train/frames\\frame061_seq_6.png',
#  './train/frames\\frame061_seq_7.png',
#  './train/frames\\frame061_seq_9.png',
#  './train/frames\\frame062_seq_1.png',
#  './train/frames\\frame062_seq_10.png',
#  './train/frames\\frame062_seq_11.png',
#  './train/frames\\frame062_seq_12.png',
#  './train/frames\\frame062_seq_13.png',
#  './train/frames\\frame062_seq_14.png',
#  './train/frames\\frame062_seq_15.png',
#  './train/frames\\frame062_seq_16.png',
#  './train/frames\\frame062_seq_2.png',
#  './train/frames\\frame062_seq_3.png',
#  './train/frames\\frame062_seq_4.png',
#  './train/frames\\frame062_seq_5.png',
#  './train/frames\\frame062_seq_6.png',
#  './train/frames\\frame062_seq_7.png',
#  './train/frames\\frame062_seq_9.png',
#  './train/frames\\frame063_seq_1.png',
#  './train/frames\\frame063_seq_10.png',
#  './train/frames\\frame063_seq_11.png',
#  './train/frames\\frame063_seq_12.png',
#  './train/frames\\frame063_seq_13.png',
#  './train/frames\\frame063_seq_14.png',
#  './train/frames\\frame063_seq_15.png',
#  './train/frames\\frame063_seq_16.png',
#  './train/frames\\frame063_seq_2.png',
#  './train/frames\\frame063_seq_3.png',
#  './train/frames\\frame063_seq_4.png',
#  './train/frames\\frame063_seq_5.png',
#  './train/frames\\frame063_seq_6.png',
#  './train/frames\\frame063_seq_7.png',
#  './train/frames\\frame063_seq_9.png',
#  './train/frames\\frame064_seq_1.png',
#  './train/frames\\frame064_seq_10.png',
#  './train/frames\\frame064_seq_11.png',
#  './train/frames\\frame064_seq_12.png',
#  './train/frames\\frame064_seq_13.png',
#  './train/frames\\frame064_seq_14.png',
#  './train/frames\\frame064_seq_15.png',
#  './train/frames\\frame064_seq_16.png',
#  './train/frames\\frame064_seq_2.png',
#  './train/frames\\frame064_seq_3.png',
#  './train/frames\\frame064_seq_4.png',
#  './train/frames\\frame064_seq_5.png',
#  './train/frames\\frame064_seq_6.png',
#  './train/frames\\frame064_seq_7.png',
#  './train/frames\\frame064_seq_9.png',
#  './train/frames\\frame065_seq_1.png',
#  './train/frames\\frame065_seq_10.png',
#  './train/frames\\frame065_seq_11.png',
#  './train/frames\\frame065_seq_12.png',
#  './train/frames\\frame065_seq_13.png',
#  './train/frames\\frame065_seq_14.png',
#  './train/frames\\frame065_seq_15.png',
#  './train/frames\\frame065_seq_16.png',
#  './train/frames\\frame065_seq_2.png',
#  './train/frames\\frame065_seq_3.png',
#  './train/frames\\frame065_seq_4.png',
#  './train/frames\\frame065_seq_5.png',
#  './train/frames\\frame065_seq_6.png',
#  './train/frames\\frame065_seq_7.png',
#  './train/frames\\frame065_seq_9.png',
#  './train/frames\\frame066_seq_1.png',
#  './train/frames\\frame066_seq_10.png',
#  './train/frames\\frame066_seq_11.png',
#  './train/frames\\frame066_seq_12.png',
#  './train/frames\\frame066_seq_13.png',
#  './train/frames\\frame066_seq_14.png',
#  './train/frames\\frame066_seq_15.png',
#  './train/frames\\frame066_seq_16.png',
#  './train/frames\\frame066_seq_2.png',
#  './train/frames\\frame066_seq_3.png',
#  ...]

# %%
# train_x = glob(os.path.join(train_path, 'frames', '*'))
# train_y = glob(os.path.join(train_path, 'labels', '*'))

# valid_x = glob(os.path.join(valid_path, 'frames', '*'))
# valid_y = glob(os.path.join(valid_path, 'labels', '*'))

# %%
# (train_x, train_y), (valid_x, valid_y) = load_data(dataset_path)
print(f'Train: {len(train_x)} - {len(train_y)}')
print(f'Valid: {len(val_x)} - {len(val_y)}')
# Out:
# Train: 1788 - 1788
# Valid: 447 - 447

# %%
train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
valid_dataset = tf_dataset(val_x, val_y, batch=batch_size)

# %%
for x, y in valid_dataset:
    print(x.shape, y.shape)
# Out:
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (2, 256, 320, 3) (2, 256, 320, 1)
# (1, 256, 320, 3) (1, 256, 320, 1)

# %%
input_shape = (height, width, 3)
model = build_unet(input_shape)
model.summary()
# Out:
# Model: "UNET"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 320, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 320, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 320, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 256, 320, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 320, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 320, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 256, 320, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 160, 64  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 160, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 128, 160, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 128, 160, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 128, 160, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 128, 160, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 128, 160, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 80, 128)  0          ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 80, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 80, 256)  1024       ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 64, 80, 256)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 80, 256)  590080      ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 80, 256)  1024       ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 64, 80, 256)  0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 40, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 40, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 40, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 32, 40, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 40, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 40, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 40, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 20, 512)  0          ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 20, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 16, 20, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 16, 20, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 16, 20, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 16, 20, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 16, 20, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 40, 512)  2097664    ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 32, 40, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 40, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 40, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 32, 40, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 40, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 40, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 32, 40, 512)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 80, 256)  524544     ['activation_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 64, 80, 512)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 80, 256)  1179904     ['concatenate_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 64, 80, 256)  1024       ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 64, 80, 256)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 80, 256)  590080      ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 64, 80, 256)  1024       ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 64, 80, 256)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 160, 12  131200     ['activation_13[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 128, 160, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 128, 160, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 128, 160, 12  512        ['conv2d_14[0][0]']
#  ormalization)                  8)
#
#  activation_14 (Activation)     (None, 128, 160, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 128, 160, 12  147584      ['activation_14[0][0]']
#                                 8)
#
#  batch_normalization_15 (BatchN  (None, 128, 160, 12  512        ['conv2d_15[0][0]']
#  ormalization)                  8)
#
#  activation_15 (Activation)     (None, 128, 160, 12  0           ['batch_normalization_15[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 320, 64  32832      ['activation_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 256, 320, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 256, 320, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 256, 320, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 256, 320, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 256, 320, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 256, 320, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 256, 320, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 256, 320, 1)  65          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31,055,297
# Trainable params: 31,043,521
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %%
opt = tf.keras.optimizers.Adam(lr)
model.compile(loss = 'binary_crossentropy', optimizer=opt, metrics=['acc'])

# %%
callbacks = [
    ModelCheckpoint(model_file, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=4),
    CSVLogger(log_file),
    EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False)
]

# %% [markdown]
# img_path = './PS3_Train/PS3_Train/seq_1/labels/frame020.png'
# image = cv2.imread(img_path)
# gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# _, binary = cv2.threshold(gray, 1, 255, cv2.THRESH_BINARY)
# binary = cv2.bitwise_not(binary)
# binary = cv2.cvtColor(binary, cv2.COLOR_GRAY2BGR)
# result = np.where(binary == [0, 0, 0], [255, 255, 255], image)
# plt.imshow(result)

# %%
model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=10,
    callbacks=callbacks
)
# Out:
# Epoch 1/10
# 894/894 [==============================] - ETA: 0s - loss: 0.1954 - acc: 0.9325
# Epoch 1: val_loss improved from inf to 0.21056, saving model to ./model\unet.h5
# 894/894 [==============================] - 125s 129ms/step - loss: 0.1954 - acc: 0.9325 - val_loss: 0.2106 - val_acc: 0.9263 - lr: 1.0000e-04
# Epoch 2/10
# 894/894 [==============================] - ETA: 0s - loss: 0.1066 - acc: 0.9592
# Epoch 2: val_loss improved from 0.21056 to 0.14236, saving model to ./model\unet.h5
# 894/894 [==============================] - 115s 129ms/step - loss: 0.1066 - acc: 0.9592 - val_loss: 0.1424 - val_acc: 0.9483 - lr: 1.0000e-04
# Epoch 3/10
# 894/894 [==============================] - ETA: 0s - loss: 0.0808 - acc: 0.9670
# Epoch 3: val_loss improved from 0.14236 to 0.14078, saving model to ./model\unet.h5
# 894/894 [==============================] - 115s 129ms/step - loss: 0.0808 - acc: 0.9670 - val_loss: 0.1408 - val_acc: 0.9483 - lr: 1.0000e-04
# Epoch 4/10
# 894/894 [==============================] - ETA: 0s - loss: 0.0700 - acc: 0.9701
# Epoch 4: val_loss improved from 0.14078 to 0.11883, saving model to ./model\unet.h5
# 894/894 [==============================] - 115s 128ms/step - loss: 0.0700 - acc: 0.9701 - val_loss: 0.1188 - val_acc: 0.9546 - lr: 1.0000e-04
# Epoch 5/10
# 894/894 [==============================] - ETA: 0s - loss: 0.0616 - acc: 0.9731
# Epoch 5: val_loss did not improve from 0.11883
# 894/894 [==============================] - 115s 128ms/step - loss: 0.0616 - acc: 0.9731 - val_loss: 0.1315 - val_acc: 0.9503 - lr: 1.0000e-04
# Epoch 6/10
# 894/894 [==============================] - ETA: 0s - loss: 0.0570 - acc: 0.9746
# Epoch 6: val_loss improved from 0.11883 to 0.11001, saving model to ./model\unet.h5
# 894/894 [==============================] - 115s 129ms/step - loss: 0.0570 - acc: 0.9746 - val_loss: 0.1100 - val_acc: 0.9586 - lr: 1.0000e-04
# Epoch 7/10
# 894/894 [==============================] - ETA: 0s - loss: 0.0514 - acc: 0.9764
# Epoch 7: val_loss did not improve from 0.11001
# 894/894 [==============================] - 116s 129ms/step - loss: 0.0514 - acc: 0.9764 - val_loss: 0.1120 - val_acc: 0.9580 - lr: 1.0000e-04
# Epoch 8/10
# 894/894 [==============================] - ETA: 0s - loss: 0.0472 - acc: 0.9779
# Epoch 8: val_loss improved from 0.11001 to 0.09820, saving model to ./model\unet.h5
# 894/894 [==============================] - 115s 129ms/step - loss: 0.0472 - acc: 0.9779 - val_loss: 0.0982 - val_acc: 0.9618 - lr: 1.0000e-04
# Epoch 9/10
# 894/894 [==============================] - ETA: 0s - loss: 0.0472 - acc: 0.9780
# Epoch 9: val_loss did not improve from 0.09820
# 894/894 [==============================] - 115s 128ms/step - loss: 0.0472 - acc: 0.9780 - val_loss: 0.1301 - val_acc: 0.9572 - lr: 1.0000e-04
# Epoch 10/10
# 894/894 [==============================] - ETA: 0s - loss: 0.0430 - acc: 0.9798
# Epoch 10: val_loss did not improve from 0.09820
# 894/894 [==============================] - 114s 127ms/step - loss: 0.0430 - acc: 0.9798 - val_loss: 0.1444 - val_acc: 0.9548 - lr: 1.0000e-04
